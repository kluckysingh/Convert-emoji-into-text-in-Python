# %% [markdown]
# <a href="https://colab.research.google.com/github/kluckysingh/Convert-emoji-into-text-in-Python/blob/main/Convert_emoji_into_text_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install demoji

# %%
import demoji

text = """Sometimes I'm sad and sometimes I'm happy but most of the times I'm 😴 and sleepy"""

result = demoji.findall(text)
print(result)
# Out:
# {'😴': 'sleeping face'}

# %%
import demoji

text = "I am happy 😄🔥💯🎉😍😴😂🤯🥳🤖"

# Find all emojis and their meanings
emojis = demoji.findall(text)

print("Emojis found:")
for emoji, meaning in emojis.items():
    print(f"{emoji} : {meaning}")
# Out:
# Emojis found:
# 🥳 : partying face
# 🤯 : exploding head
# 😍 : smiling face with heart-eyes
# 😄 : grinning face with smiling eyes
# 😴 : sleeping face
# 💯 : hundred points
# 🔥 : fire
# 😂 : face with tears of joy
# 🤖 : robot
# 🎉 : party popper
